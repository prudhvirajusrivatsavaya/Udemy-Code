# %% [markdown]
# <img src="../Pics/MLSb-T.png" width="160">
# <br><br>
# <center><u><H1>Word2Vec-Skipgram-Keras</H1></u></center>

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.log_device_placement = True
sess = tf.Session(config=config)
set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from keras.models import Sequential, Model
from keras.layers import Embedding, Reshape, Activation, Input
from keras.layers.merge import Dot
from keras.utils import np_utils
from keras.utils.data_utils import get_file
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import skipgrams
import gensim

# %%
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer

# %%
remove_terms = punctuation + '0123456789'
remove_terms
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~0123456789'

# %%
def preprocessing(text):
    words = word_tokenize(text)
    tokens = [w for w in words if w.lower() not in remove_terms]
    #stopw = stopwords.words('english')
    #tokens = [token for token in tokens if token not in stopw]
    # remove words less than three letters
    #tokens = [word for word in tokens if len(word)>=3]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # lemmatize
    lemma = WordNetLemmatizer()
    tokens = [lemma.lemmatize(word) for word in tokens]
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

# %%
#path = get_file('cosmos.txt', origin="https://www.gutenberg.org/files/8172/8172-0.txt")

# %%
corpus = open("../data/History_of_Astronomy.txt", encoding="utf8").readlines()

# %%
corpus = [preprocessing(sentence) for sentence in corpus if sentence.strip() !='']
corpus
# Out:
# ['Project Gutenberg EBook of History of Astronomy by George Forbes',
#  'Title History of Astronomy',
#  'Author George Forbes',
#  'Illustration SIR ISAAC NEWTON From the bust by Roubiliac In Trinity',
#  'College Cambridge',
#  'HISTORY OF ASTRONOMY',
#  'BY',
#  'GEORGE FORBES',
#  'INST',
#  'FORMERLY PROFESSOR OF NATURAL PHILOSOPHY ANDERSON COLLEGE GLASGOW',
#  'AUTHOR OF THE TRANSIT OF VENUS RENDU THEORY OF THE GLACIERS OF',
#  'SAVOY ETC',
#  'CONTENTS',
#  'PREFACE',
#  'BOOK I THE GEOMETRICAL PERIOD',
#  'PRIMITIVE ASTRONOMY AND ASTROLOGY',
#  'ANCIENT ASTRONOMY CHINESE AND CHALDÆANS',
#  'ANCIENT GREEK ASTRONOMY',
#  'THE REIGN OF EPICYCLES FROM PTOLEMY TO COPERNICUS',
#  'BOOK II THE DYNAMICAL PERIOD',
#  'DISCOVERY OF THE TRUE SOLAR SYSTEM TYCHO BRAHE KEPLER',
#  'GALILEO AND THE TELESCOPE NOTIONS OF GRAVITY BY HORROCKS ETC',
#  'SIR ISAAC NEWTON LAW OF UNIVERSAL GRAVITATION',
#  'NEWTON SUCCESSORS HALLEY EULER LAGRANGE LAPLACE ETC',
#  'DISCOVERY OF NEW PLANETS HERSCHEL PIAZZI ADAMS AND LE',
#  'VERRIER',
#  'BOOK III OBSERVATION',
#  'INSTRUMENTS OF PRECISION SIZE OF THE SOLAR SYSTEM',
#  'HISTORY OF THE TELESCOPE SPECTROSCOPE',
#  'BOOK IV THE PHYSICAL PERIOD',
#  'THE SUN',
#  'THE MOON AND PLANETS',
#  'COMETS AND METEORS',
#  'THE STARS AND NEBULÆ',
#  'INDEX',
#  'PREFACE',
#  'An attempt ha been made in these page to trace the evolution of',
#  'intellectual thought in the progress of astronomical discovery and',
#  'by recognising the different point of view of the different age to',
#  'give due credit even to the ancient No one can expect in a history',
#  'of astronomy of limited size to find a treatise on practical or on',
#  'theoretical astronomy nor a complete descriptive astronomy and',
#  'still le a book on speculative astronomy Something of each of',
#  'these is essential however for tracing the progress of thought and',
#  'knowledge which it is the object of this History to describe',
#  'The progress of human knowledge is measured by the increased habit of',
#  'looking at fact from new point of view a much a by the',
#  'accumulation of fact The mental capacity of one age doe not seem to',
#  'differ from that of other age but it is the imagination of new',
#  'point of view that give a wider scope to that capacity And this is',
#  'cumulative and therefore progressive Aristotle viewed the solar',
#  'system a a geometrical problem Kepler and Newton converted the point',
#  'of view into a dynamical one Aristotle mental capacity to',
#  'understand the meaning of fact or to criticise a train of reasoning',
#  'may have been equal to that of Kepler or Newton but the point of view',
#  'wa different',
#  'Then again new point of view are provided by the invention of new',
#  'method in that system of logic which we call mathematics All that',
#  'mathematics can do is to assure u that a statement A is equivalent to',
#  'statement B C D or is one of the fact expressed by the statement',
#  'B C D so that we may know if B C and D are true then A is true',
#  'To many people our inability to understand all that is contained in',
#  'statement B C and D without the cumbrous process of a mathematical',
#  'demonstration prof the feebleness of the human mind a a logical',
#  'machine For it required the new point of view imagined by Newton',
#  'analysis to enable people to see that so far a planetary orbit are',
#  'concerned Kepler three law B C D were identical with Newton',
#  'law of gravitation A No one recognises more than the mathematical',
#  'astronomer this feebleness of the human intellect and no one is more',
#  'conscious of the limitation of the logical process called',
#  'mathematics which even now ha not solved directly the problem of',
#  'only three body',
#  'These reflection arising from the writing of this History go to',
#  'explain the invariable humility of the great mathematical astronomer',
#  'Newton comparison of himself to the child on the seashore applies to',
#  'them all As each new discovery open up it may be boundless ocean',
#  'for investigation for wonder and for admiration the great',
#  'astronomer refusing to accept mere hypothesis a true have founded',
#  'upon these discovery a science a exact in it observation of fact',
#  'a in theory So it is that these men who have built up the most',
#  'sure and most solid of all the science refuse to invite others to',
#  'join them in vain speculation The writer ha therefore in this',
#  'short History tried to follow that great master Airy whose pupil he',
#  'wa and the key to whose character wa exactness and accuracy and he',
#  'recognises that Science is impotent except in her own limited sphere',
#  'It ha been necessary to curtail many part of the History in the',
#  'attempt perhaps a hopeless one to lay before the reader in a limited',
#  'space enough about each age to illustrate it tone and spirit the',
#  'ideal of the worker the gradual addition of new point of view and',
#  'of new mean of investigation',
#  'It would indeed be a pleasure to entertain the hope that these page',
#  'might among new recruit arouse an interest in the greatest of all',
#  'the science or that those who have handled the theoretical or',
#  'practical side might be led by them to read in the original some of',
#  'the classic of astronomy Many student have much compassion for the',
#  'schoolboy of who is not allowed the luxury of learning the art',
#  'of reasoning from him who still remains it greatest',
#  'exponent Euclid These student pity also the man of who',
#  'is not to be allowed to read in the original Latin of the brilliant',
#  'Kepler how he wa able by observation taken from a moving platform',
#  'the earth of the direction of a moving object Mars to deduce the',
#  'exact shape of the path of each of these planet and their actual',
#  'position on these path at any time Kepler masterpiece is one of',
#  'the most interesting book that wa ever written combining wit',
#  'imagination ingenuity and certainty',
#  'Lastly it must be noted that a a History of England can not deal',
#  'with the present Parliament so also the unfinished research and',
#  'untested hypothesis of many astronomer of can not be',
#  'included among the record of the History of Astronomy The writer',
#  'regret the necessity that thus arises of leaving without mention the',
#  'name of many who are now making history in astronomical work',
#  'F',
#  '',
#  'BOOK I THE GEOMETRICAL PERIOD',
#  'PRIMITIVE ASTRONOMY AND ASTROLOGY',
#  'The growth of intelligence in the human race ha it counterpart in',
#  'that of the individual especially in the earliest stage',
#  'Intellectual activity and the development of reasoning power are in',
#  'both case based upon the accumulation of experience and on the',
#  'comparison classification arrangement and nomenclature of these',
#  'experience During the infancy of each the succession of event can',
#  'be watched but there can be no anticipation',
#  'Experience alone in both case lead to the idea of cause and effect',
#  'a a principle that seems to dominate our present universe a a rule',
#  'for predicting the course of event and a a guide to the choice of a',
#  'course of action This idea of cause and effect is the most potent',
#  'factor in developing the history of the human race a of the',
#  'individual',
#  'In no realm of nature is the principle of cause and effect more',
#  'conspicuous than in astronomy and we fall into the habit of thinking',
#  'of it law a not only being unchangeable in our universe but',
#  'necessary to the conception of any universe that might have been',
#  'substituted in it place The first inhabitant of the world were',
#  'compelled to accommodate their act to the daily and annual',
#  'alternation of light and darkness and of heat and cold a much a to',
#  'the irregular change of weather attack of disease and the fortune',
#  'of war They soon came to regard the influence of the sun in',
#  'connection with light and heat a a cause This led to a search for',
#  'other sign in the heaven If the appearance of a comet wa sometimes',
#  'noted simultaneously with the death of a great ruler or an eclipse',
#  'with a scourge of plague these might well be looked upon a cause in',
#  'the same sense that the veering or backing of the wind is regarded a',
#  'a cause of fine or foul weather',
#  'For these reason we find that the earnest men of all age have',
#  'recorded the occurrence of comet eclipse new star meteor',
#  'shower and remarkable conjunction of the planet a well a',
#  'plague and famine flood and drought war and the death of great',
#  'ruler Sometimes they thought they could trace connection which',
#  'might lead them to say that a comet presaged famine or an eclipse',
#  'war',
#  'Even if these men were sometimes led to evolve law of cause and',
#  'effect which now seem to u absurd let u be tolerant and gratefully',
#  'acknowledge that these astrologer when they suggested such working',
#  'hypothesis were laying the foundation of observation and deduction',
#  'If the ancient Chaldæans gave to the planetary conjunction an',
#  'influence over terrestrial event let u remember that in our own',
#  'time people have searched for connection between terrestrial',
#  'condition and period of unusual prevalence of sun spot while De la',
#  'Rue Loewy and Balfour Stewart thought they found a connection',
#  'between display and the planetary position Thus we find',
#  'scientific men even in our own time responsible for the belief that',
#  'storm in the Indian Ocean the fertility of German vine famine in',
#  'India and high or low in Egypt follow the planetary',
#  'position',
#  'And again the desire to foretell the weather is so laudable that we',
#  'can not blame the ancient Greeks for announcing the influence of the',
#  'moon with a much confidence a it is affirmed in Lord Wolseley',
#  'Pocket',
#  'Even if the scientific spirit of observation and deduction astronomy',
#  'ha sometimes led to erroneous system for predicting terrestrial',
#  'event astrology we owe to the old astronomer and astrologer alike',
#  'the deepest gratitude for their diligence in recording astronomical',
#  'event For out of the scanty record which have survived the',
#  'destructive act of fire and flood of monarch and mob we have',
#  'found much that ha helped to a fuller knowledge of the heavenly',
#  'motion than wa possible without these record',
#  'So Hipparchus about and Ptolemy a little later were able',
#  'to use the observation of Chaldæan astrologer a well a those of',
#  'Alexandrian astronomer and to make some discovery which have',
#  'helped the progress of astronomy in all age So also Cowell',
#  'ha examined the mark made on the baked brick used by the Chaldæans',
#  'for recording the eclipse of and and ha thereby',
#  'been enabled in the last few year to correct the lunar table of',
#  'Hansen and to find a more accurate value for the secular acceleration',
#  'of the moon longitude and the node of her orbit than any that could',
#  'be obtained from modern observation made with instrument of the',
#  'highest precision',
#  'So again Hind wa enabled to trace back the period during',
#  'which Halley comet ha been a member of the solar system and to',
#  'identify it in the Chinese observation of comet a far back a',
#  'Cowell and Cromellin extended the date to In the same',
#  'way the comet ha been traced back in the Chinese record to',
#  '',
#  'The theoretical view founded on Newton great law of universal',
#  'gravitation led to the conclusion that the inclination of the earth',
#  'equator to the plane of her orbit the obliquity of the ecliptic ha',
#  'been diminishing slowly since prehistoric time and this fact ha',
#  'been confirmed by Egyptian and Chinese observation on the length of',
#  'the shadow of a vertical pillar made thousand of year before the',
#  'Christian era in summer and winter',
#  'There are other reason why we must be tolerant of the crude notion',
#  'of the ancient The historian wishing to give credit wherever it may',
#  'be due is met by two difficulty Firstly only a few record of',
#  'very ancient astronomy are extant and the authenticity of many of',
#  'these is open to doubt Secondly it is very difficult to divest',
#  'ourselves of present knowledge and to appreciate the originality of',
#  'thought required to make the first beginning',
#  'With regard to the first point we are generally dependent upon',
#  'history written long after the event The astronomy of Egyptians',
#  'Babylonians and Assyrians is known to u mainly through the Greek',
#  'historian and for information about the Chinese we rely upon the',
#  'research of traveller and missionary in comparatively recent',
#  'time The testimony of the Greek writer ha fortunately been',
#  'confirmed and we now have in addition a mass of fact translated from',
#  'the original sculpture papyrus and inscribed brick dating back',
#  'thousand of year',
#  'In attempting to appraise the effort of the beginner we must',
#  'remember that it wa natural to look upon the earth a all the first',
#  'astronomer did a a circular plane surrounded and bounded by the',
#  'heaven which wa a solid vault or hemisphere with it concavity',
#  'turned downwards The star seemed to be fixed on this vault the',
#  'moon and later the planet were seen to crawl over it It wa a',
#  'great step to look on the vault a a hollow sphere carrying the sun',
#  'too It must have been difficult to believe that at midday the star',
#  'are shining a brightly in the blue sky a they do at night It must',
#  'have been difficult to explain how the sun having set in the west',
#  'could get back to rise in the east without being seen it wa',
#  'always the same sun It wa a great step to suppose the earth to be',
#  'spherical and to ascribe the diurnal motion to it rotation',
#  'Probably the greatest step ever made in astronomical theory wa the',
#  'placing of the sun moon and planet at different distance from the',
#  'earth instead of having them stuck on the vault of heaven It wa a',
#  'transition from flatland to a space of three dimension',
#  'Great progress wa made when systematic observation began such a',
#  'following the motion of the moon and planet among the star and the',
#  'inferred motion of the sun among the star by observing their',
#  'the time of year when a star',
#  'would first be seen to rise at sunrise and when it could last be seen',
#  'to rise at sunset The grouping of the star into constellation and',
#  'recording their place wa a useful observation The theoretical',
#  'prediction of eclipse of the sun and moon and of the motion of the',
#  'planet among the star became later the highest goal in astronomy',
#  'To not one of the above important step in the progress of astronomy',
#  'can we assign the author with certainty Probably many of them were',
#  'independently taken by Chinese Indian Persian Tartar Egyptian',
#  'Babylonian Assyrian Phoenician and Greek astronomer And we have',
#  'not a particle of information about the discovery which may have',
#  'been great by other people by the Druids the Mexicans and the',
#  'Peruvians for example',
#  'We do know this that all nation required to have a calendar The',
#  'solar year the lunar month and the day were the unit and it is',
#  'owing to their incommensurability that we find so many calendar',
#  'proposed and in use at different time The only object to be attained',
#  'by comparing the chronology of ancient race is to fix the actual',
#  'date of observation recorded and this is not a part of a history of',
#  'astronomy',
#  'In conclusion let u bear in mind the limited point of view of the',
#  'ancient when we try to estimate their merit Let u remember that the',
#  'first astronomy wa of two dimension the second astronomy wa of',
#  'three dimension but still purely geometrical Since Kepler day we',
#  'have had a dynamical astronomy',
#  'FOOTNOTES',
#  'Trans xxiii Sun by',
#  'Stewart Also Trans Also Ernest Brown in',
#  'Monthly',
#  'Monthly Sup',
#  'Illustration CHALDÆAN BAKED BRICK OR TABLET and reverse',
#  'Containing record of solar eclipse used lately by',
#  'Cowell for rendering the lunar theory more accurate than wa possible',
#  'by finest modern observation British Museum collection',
#  'No',
#  'Monthly vol',
#  'E vol',
#  'ANCIENT ASTRONOMY THE CHINESE AND CHALDÆANS',
#  'The last section must have made clear the difficulty the way of',
#  'assigning to the ancient nation their proper place in the development',
#  'of primitive notion about astronomy The fact that some alleged',
#  'observation date back to a period before the Chinese had invented the',
#  'art of writing lead immediately to the question how far tradition can',
#  'be trusted',
#  'Our first detailed knowledge wa gathered in the far East by',
#  'traveller and by the Jesuit priest and wa published in the',
#  'eighteenth century The Asiatic Society of Bengal contributed',
#  'translation of Brahmin literature The two principal source of',
#  'knowledge about Chinese astronomy were supplied first by Father',
#  'Souciet who in published Astronomical',
#  'Geographical Chronological and drawn from ancient',
#  'Chinese book and later by Father who in',
#  'published of the Chinese Empire translated from',
#  '',
#  'Bailly in his drew from these and',
#  'other source the conclusion that all we know of the astronomical',
#  'learning of the Chinese Indians Chaldæans Assyrians and Egyptians',
#  'is but the remnant of a far more complete astronomy of which no trace',
#  'can be found',
#  'Delambre in his de',
#  'ridicule the opinion of Bailly and considers that the progress made',
#  'by all of these nation is insignificant',
#  'It will be well now to give an idea of some of the astronomy of the',
#  'ancient not yet entirely discredited China and Babylon may be taken',
#  'a typical example',
#  'It would appear that Fohi the first emperor reigned',
#  'about and shortly afterwards made a sphere to',
#  'represent the motion of the celestial body It is also mentioned',
#  'in the book called supposed to have been written in',
#  'that a similar sphere wa made in the time of Yao',
#  'It is said that the Emperor Chueni saw five',
#  'planet in conjunction the same day that the sun and moon were in',
#  'conjunction This is discussed by Father Martin MSS of De Lisle',
#  'also by Desvignolles Mem Acad Berlin vol and by',
#  'Kirsch ditto vol who both found that Mars Jupiter',
#  'Saturn and Mercury were all between the eleventh and eighteenth',
#  'degree of Pisces all visible together in the evening on February',
#  'while on the same day the sun and moon were in',
#  'conjunction at and that on March the moon wa in',
#  'conjunction with the other four planet But this need confirmation',
#  'Yao referred to above gave instruction to his astronomer to',
#  'determine the position of the solstice and equinox and they',
#  'reported the name of the star in the place occupied by the sun at',
#  'these season and in he gave them further order If this',
#  'account be true it show a knowledge that the vault of heaven is a',
#  'complete sphere and that star are shining at although',
#  'eclipsed by the sun brightness',
#  'It is also asserted in the book called that in the',
#  'time of Yao the year wa known to have day and that he',
#  'adopted day and added an intercalary day every four year a in',
#  'the Julian Calendar This may be true or not but the ancient Chinese',
#  'certainly seem to have divided the circle into degree To learn',
#  'the length of the year needed only patient observation a',
#  'characteristic of the Chinese but many younger nation got into a',
#  'terrible mess with their calendar from ignorance of the year length',
#  'It is stated that in the royal astronomer Hi and Ho failed',
#  'to predict an eclipse It probably created great terror for they were',
#  'executed in punishment for their neglect If this account be true it',
#  'mean that in the century some rule for calculating',
#  'eclipse wa in use Here again patient observation would easily',
#  'lead to the detection of the cycle known to the',
#  'Chaldeans a the It consists of lunation and in',
#  'that time the pole of the moon orbit revolves just once round the',
#  'pole of the ecliptic and for this reason the eclipse in one cycle',
#  'are repeated with very slight modification in the next cycle and so',
#  'on for many century',
#  'It may be that the neglect of their duty by Hi and Ho and their',
#  'punishment influenced Chinese astronomy or that the succeeding',
#  'record have not been available to later scholar but the fact',
#  'remains that although at long interval observation were made of',
#  'eclipse comet and falling star and of the position of the',
#  'solstice and of the obliquity of the ecliptic record become rare',
#  'until when eclipse began to be recorded once more with some',
#  'approach to continuity Shortly afterwards notice of comet were',
#  'added Biot gave a list of these and John Williams in',
#  'published of Comets from to',
#  'Extracted from the Chinese',
#  'With regard to those century concerning which we have no',
#  'astronomical Chinese record it is fair to state that it is recorded',
#  'that some century before the Christian era in the reign of',
#  'all the classical and scientific book that could be',
#  'found were ordered to be destroyed If true our loss therefrom is a',
#  'great a from the burning of the Alexandrian library by the Caliph',
#  'Omar He burnt all the book because he held that they must be either',
#  'consistent or inconsistent with the Koran and in the one case they',
#  'were superfluous in the other case objectionable',
#  'Until the last half century historian were',
#  'accustomed to look back upon the Greeks who led the world from the',
#  'fifth to the third century a the pioneer of art literature',
#  'and science But the excavation and research of later year make u',
#  'more ready to grant that in science a in art the Greeks only',
#  'developed what they derived from the Egyptians Babylonians and',
#  'Assyrians The Greek historian said a much in fact and modern',
#  'commentator used to attribute the assertion to undue modesty Since',
#  'however the record of the library have been unearthed it ha been',
#  'recognised that the Babylonians were in no way inferior in the matter',
#  'of original scientific investigation to other race of the same era',
#  'The Chaldæans being the most ancient Babylonians held the same',
#  'station and dignity in the State a did the priest in Egypt and',
#  'spent all their time in the study of philosophy and astronomy and the',
#  'art of divination and astrology They held that the world of which we',
#  'have a conception is an eternal world without any beginning or ending',
#  'in which all thing are ordered by rule supported by a divine',
#  'providence and that the heavenly body do not move by chance nor by',
#  'their own will but by the determinate will and appointment of the',
#  'god They recorded these movement but mainly in the hope of tracing',
#  'the will of the god in mundane affair Ptolemy about',
#  'made use of Babylonian eclipse in the eighth century for',
#  'improving his solar and lunar table',
#  'Fragments of a library at Agade have been preserved at Nineveh from',
#  'which we learn that the were even then divided into',
#  'constellation which were known by the name which they bear to this',
#  'day and that the sign of the zodiac were used for determining the',
#  'course of the sun moon and of the five planet Mercury Venus',
#  'Mars Jupiter and Saturn',
#  'We have record of observation carried on under Asshurbanapal who',
#  'sent astronomer to different part to study celestial phenomenon Here',
#  'is one',
#  'To the Director of Observations My Lord his humble servant',
#  'Great Astronomer of Nineveh writes thus May Nabu',
#  'and Marduk be propitious to the Director of these Observations my',
#  'Lord The fifteenth day we observed the Node of the moon and the moon',
#  'wa eclipsed',
#  'The Phoenicians are supposed to have used the star for navigation',
#  'but there are no record The Egyptian priest tried to keep such',
#  'astronomical knowledge a they possessed to themselves It is probable',
#  'that they had arbitrary rule for predicting eclipse All that wa',
#  'known to the Greeks about Egyptian science is to be found in the',
#  'writing of Diodorus Siculus But confirmatory and more authentic',
#  'fact have been derived from late exploration Thus we learn from',
#  'Knobel about the Jewish calendar date on record of land',
#  'sale in Aramaic papyrus at Assuan translated by Professor Sayce',
#  'and Cowley that the lunar cycle of nineteen year wa used',
#  'by the Jews in the fifth century the present reformed Jewish',
#  'calendar dating from the fourth century a date a little more',
#  'than a century after the grandfather and of those',
#  'whose business is recorded had fled into Egypt with Jeremiah Sayce',
#  'and that the order of intercalation at that time wa not',
#  'dissimilar to that in use at the present day',
#  'Then again Knobel reminds u of the most interesting discovery a few',
#  'year ago by Father Strassmeier of a Babylonian tablet recording a',
#  'partial lunar eclipse at Babylon in the seventh year of Cambyses on',
#  'the fourteenth day of the Jewish month Tammuz Ptolemy in the',
#  'Almagest Suntaxis say it occurred in the seventh year of Cambyses',
#  'on the night of the seventeenth and eighteenth of the Egyptian month',
#  'Phamenoth Pingré and Oppolzer fix the date July Thus',
#  'are the relation of the chronology of Jews and Egyptians',
#  'established by these exploration',
#  'FOOTNOTES',
#  'These ancient date are uncertain',
#  'Monthly vol No March',
#  'ANCIENT GREEK ASTRONOMY',
#  'We have our information about the earliest Greek astronomy from',
#  'Herodotus born He put the tradition into writing Thales',
#  'is said to have predicted an eclipse which caused much',
#  'alarm and ended the battle between the Medes and Lydians Airy fixed',
#  'the date May But other modern astronomer give',
#  'different date Thales went to Egypt to study science and learnt',
#  'from it priest the length of the year which wa kept a profound',
#  'secret and the sign of the zodiac and the position of the',
#  'solstice He held that the sun moon and star are not mere spot on',
#  'the heavenly vault but solid that the moon derives her light from',
#  'the sun and that this fact explains her phase that an eclipse of',
#  'the moon happens when the earth cut off the sun light from her He',
#  'supposed the earth to be flat and to float upon water He determined',
#  'the ratio of the sun diameter to it orbit and apparently made out',
#  'the diameter correctly a half a degree He left nothing in writing',
#  'His successor Anaximander and Anaximenes',
#  'held absurd notion about the sun moon and star while',
#  'Heraclitus supposed that the star were lighted each',
#  'night like lamp and the sun each morning Parmenides supposed the',
#  'earth to be a sphere',
#  'Pythagoras visited Egypt to study science He deduced',
#  'his system in which the earth revolves in an orbit from fantastic',
#  'first principle of which the following are example The circular',
#  'motion is the most perfect motion Fire is more worthy than earth',
#  'Ten is the perfect number He wrote nothing but is supposed to have',
#  'said that the earth moon five planet and fixed star all revolve',
#  'round the sun which itself revolves round an imaginary central fire',
#  'called the Antichthon Copernicus in the sixteenth century claimed',
#  'Pythagoras a the founder of the system which he Copernicus revived',
#  'Anaxagoras born studied astronomy in Egypt He explained',
#  'the return of the sun to the east each morning by it going under the',
#  'flat earth in the night He held that in a solar eclipse the moon',
#  'hide the sun and in a lunar eclipse the moon enters the earth',
#  'shadow both excellent opinion But he entertained absurd idea of',
#  'the vortical motion of the heaven whisking stone into the sky there',
#  'to be ignited by the fiery firmament to form star He wa prosecuted',
#  'for this unsettling opinion and for maintaining that the moon is an',
#  'inhabited earth He wa defended by Pericles',
#  'Solon dabbled like many others in reform of the calendar The',
#  'common year of the Greeks originally had day twelve month of',
#  'thirty day Solon year wa day It is obvious that these',
#  'erroneous year would before long remove the summer to January and',
#  'the winter to July To prevent this it wa customary at regular',
#  'interval to intercalate day or month Meton introduced a',
#  'reform based on the cycle This is not the same a the',
#  'Egyptian and Chaldean eclipse cycle called of',
#  'lunation or a little over eighteen year The Metonic cycle is',
#  'lunation or nineteen year after which period the sun and moon',
#  'occupy the same position relative to the star It is still used for',
#  'fixing the date of Easter the number of the year in Melon cycle',
#  'being the golden number of our Melon system divided',
#  'the lunation into month of thirty day and omitted every',
#  'day Of the nineteen year twelve had twelve month and',
#  'seven had thirteen month',
#  'Callippus used a cycle four time a long lunation',
#  'but one day short of Melon year This wa more correct',
#  'Eudoxus is said to have travelled with Plato in',
#  'Egypt He made astronomical observation in Asia Minor Sicily and',
#  'Italy and described the starry heaven divided into constellation',
#  'His name is connected with a planetary theory which a generally',
#  'stated sound most fanciful He imagined the fixed star to be on a',
#  'vault of heaven and the sun moon and planet to be upon similar',
#  'vault or sphere revolving sphere in all the motion of',
#  'each planet being resolved into it component and a separate sphere',
#  'being assigned for each component motion Callippus',
#  'increased the number to It is now generally accepted',
#  'that the real existence of these sphere wa not suggested but the',
#  'idea wa only a mathematical conception to facilitate the construction',
#  'of table for predicting the place of the heavenly body',
#  'Aristotle summed up the state of astronomical knowledge',
#  'in his time and held the earth to be fixed in the centre of the',
#  'world',
#  'Nicetas Heraclides and Ecphantes supposed the earth to revolve on',
#  'it axis but to have no orbital motion',
#  'The short epitome so far given illustrates the extraordinary deductive',
#  'method adopted by the ancient Greeks But they went much farther in',
#  'the same direction They seem to have been in great difficulty to',
#  'explain how the earth is supported just a were those who invented',
#  'the myth of Atlas or the Indians with the tortoise Thales thought',
#  'that the flat earth floated on water Anaxagoras thought that being',
#  'flat it would be buoyed up and supported on the air like a kite',
#  'Democritus thought it remained fixed like the donkey between two',
#  'bundle of hay because it wa equidistant from all part of the',
#  'containing sphere and there wa no reason why it should incline one',
#  'way rather than another Empedocles attributed it state of rest to',
#  'centrifugal force by the rapid circular movement of the heaven a',
#  'water is stationary in a pail when whirled round by a string',
#  'Democritus further supposed that the inclination of the flat earth to',
#  'the ecliptic wa due to the greater weight of the southern part owing',
#  'to the exuberant vegetation',
#  'For further reference to similar effort of imagination the reader is',
#  'referred to Sir George Cornwall Lewis Survey of the',
#  'Astronomy of the London His list of authority',
#  'is very complete but some of his conclusion are doubtful At',
#  'of that work he record the real opinion of Socrates a set forth by',
#  'Xenophon and the reader will perhaps sympathise with Socrates in',
#  'his view on contemporary astronomy',
#  'With regard to astronomy he Socrates considered a knowledge of it',
#  'desirable to the extent of determining the day of the year or month',
#  'and the hour of the night but a to learning the course of the',
#  'star to be occupied with the planet and to inquire about their',
#  'distance from the earth and their orbit and the cause of their',
#  'motion he strongly objected to such a waste of valuable time He',
#  'dwelt on the contradiction and conflicting opinion of the physical',
#  'philosopher and in fine he held that the speculator on the',
#  'universe and on the law of the heavenly body were no better than',
#  'madman i',
#  'Plato born the pupil of Socrates the of',
#  'Euclid and a follower of Pythagoras studied science in his travel',
#  'in Egypt and elsewhere He wa held in so great reverence by all',
#  'learned men that a problem which he set to the astronomer wa the',
#  'keynote to all astronomical investigation from this date till the time',
#  'of Kepler in the sixteenth century He proposed to astronomer',
#  'problem of representing the course of the planet by circular and',
#  'uniform',
#  'Systematic observation among the Greeks began with the rise of the',
#  'Alexandrian school Aristillus and Timocharis set up instrument and',
#  'fixed the position of the zodiacal star near to which all the',
#  'planet in their orbit pas thus facilitating the determination of',
#  'planetary motion Aristarchus showed that the sun must',
#  'be at least nineteen time a far off a the moon which is far short',
#  'of the mark He also found the sun diameter correctly to be half a',
#  'degree Eratosthenes measured the inclination to the',
#  'equator of the sun apparent path in the heaven he',
#  'measured the obliquity of the ecliptic making it confirming',
#  'our knowledge of it continuous diminution during historical time He',
#  'measured an arc of meridian from Alexandria to Syene Assuan and',
#  'found the difference of latitude by the length of a shadow at noon',
#  'summer solstice He deduced the diameter of the earth',
#  'stadium Unfortunately we do not know the length of the stadium he',
#  'used',
#  'Hipparchus may be regarded a the founder of',
#  'observational astronomy He measured the obliquity of the ecliptic',
#  'and agreed with Eratosthenes He altered the length of the tropical',
#  'year from day hour to day hour minute still',
#  'four minute too much He measured the equation of time and the',
#  'irregular motion of the sun and allowed for this in his calculation',
#  'by supposing that the centre about which the sun move uniformly is',
#  'situated a little distance from the fixed earth He called this point',
#  'the The line from the earth to the excentric wa',
#  'called the of A circle having this centre wa',
#  'called the and he supposed that a radius drawn to the',
#  'sun from the excentric pass over equal arc on the equant in equal',
#  'time He then computed table for predicting the place of the sun',
#  'He proceeded in the same way to compute Lunar table Making use of',
#  'Chaldæan eclipse he wa able to get an accurate value of the moon',
#  'mean motion Halley in compared this value with his own',
#  'measurement and so discovered the acceleration of the moon mean',
#  'motion This wa conclusively established but could not be explained',
#  'by the Newtonian theory for quite a long time He determined the',
#  'plane of the moon orbit and it inclination to the ecliptic The',
#  'motion of this plane round the pole of the ecliptic once in eighteen',
#  'year complicated the problem He located the moon excentric a he',
#  'had done the sun He also discovered some of the minor',
#  'irregularity of the moon motion due a Newton theory prof',
#  'to the disturbing action of the sun attraction',
#  'In the year Hipparchus observed a new star This upset every',
#  'notion about the permanence of the fixed star He then set to work to',
#  'catalogue all the principal star so a to know if any others appeared',
#  'or disappeared Here his experience resembled those of several later',
#  'astronomer who when in search of some special object have been',
#  'rewarded by a discovery in a totally different direction On comparing',
#  'his star position with those of Timocharis and Aristillus he found no',
#  'star that had appeared or disappeared in the interval of year',
#  'but he found that all the star seemed to have changed their place',
#  'with reference to that point in the heaven where the ecliptic is',
#  'from the pole of the earth the equinox He found that this',
#  'could be explained by a motion of the equinox in the direction of the',
#  'apparent diurnal motion of the star This discovery of of',
#  'the which take place at the rate of every year wa',
#  'necessary for the progress of accurate astronomical observation It',
#  'is due to a steady revolution of the earth pole round the pole of',
#  'the ecliptic once in year in the opposite direction to the',
#  'planetary revolution',
#  'Hipparchus wa also the inventor of trigonometry both plane and',
#  'spherical He explained the method of using eclipse for determining',
#  'the longitude',
#  'In connection with Hipparchus great discovery it may be mentioned',
#  'that modern astronomer have often attempted to fix date in history',
#  'by the effect of precession of the equinox At about the date',
#  'when the Great Pyramid may have been built γDraconis wa near to the',
#  'pole and must have been used a the In the north face of',
#  'the Great Pyramid is the entrance to an inclined passage and six of',
#  'the nine pyramid at Gizeh posse the same feature all the passage',
#  'being inclined at an angle between and to the horizon and in',
#  'the plane of the meridian It also appears that year',
#  'ago about an observer at the lower end of the',
#  'passage would be able to see γDraconis the then at it',
#  'lower culmination It ha been suggested that the passage wa made',
#  'for this purpose On other ground the date assigned to the Great',
#  'Pyramid is',
#  'The Chaldæans gave name to constellation now invisible from',
#  'Babylon which would have been visible in at which date it',
#  'is claimed that these people were studying astronomy',
#  'In the Odyssey Calypso directs Odysseus in accordance with',
#  'Phoenician rule for navigating the Mediterranean to keep the Great',
#  'Bear ever on the left a he traversed the deep when sailing from the',
#  'pillar of Hercules Gibraltar to Corfu Yet such a course taken now',
#  'would land the traveller in Africa Odysseus is said in his voyage in',
#  'springtime to have seen the Pleiades and Arcturus setting late which',
#  'seemed to early commentator a proof of Homer inaccuracy Likewise',
#  'Homer both in the and in the',
#  'xviii asserts that the Great Bear never set in those',
#  'latitude Now it ha been found that the precession of the equinox',
#  'explains all these puzzle show that in springtime on the',
#  'Mediterranean the Bear wa just above the horizon near the sea but',
#  'not touching it between and and fix the date of',
#  'the poem thus confirming other evidence and establishing Homer',
#  'character for accuracy',
#  'The orientation of Egyptian temple and Druidical stone is such',
#  'that possibly they were so placed a to assist in the observation of',
#  'the heliacal rising of certain star If the star were known',
#  'this would give an approximate date Up to the present the result of',
#  'these investigation are far from being conclusive',
#  'Ptolemy wrote the Suntaxis or Almagest which includes a',
#  'cyclopedia of astronomy containing a summary of knowledge at that',
#  'date We have no evidence beyond his own statement that he wa a',
#  'practical observer He theorised on the planetary motion and held',
#  'that the earth is fixed in the centre of the universe He adopted the',
#  'excentric and equant of Hipparchus to explain the unequal motion of',
#  'the sun and moon He adopted the epicycle and deferents which had',
#  'been used by Apollonius and others to explain the retrograde motion',
#  'of the planet We who know that the earth revolves round the sun',
#  'once in a year can understand that the apparent motion of a planet is',
#  'only it motion relative to the earth If then we suppose the earth',
#  'fixed and the sun to revolve round it once a year and the planet',
#  'each in it own period it is only necessary to impose upon each of',
#  'these an additional motion to enable u to represent truly',
#  'the apparent motion This way of looking at the apparent motion',
#  'show why each planet when nearest to the earth seems to move for a',
#  'time in a retrograde direction The attempt of Ptolemy and others of',
#  'his time to explain the retrograde motion in this way were only',
#  'approximate Let u suppose each planet to have a bar with one end',
#  'centred at the earth If at the other end of the bar one end of a',
#  'shorter bar is pivotted having the planet at it other end then the',
#  'planet is given an annual motion in the secondary circle the',
#  'epicycle whose centre revolves round the earth on the primary circle',
#  'the at a uniform rate round the excentric Ptolemy',
#  'supposed the centre of the epicycle of Mercury and Venus to be on a',
#  'bar passing through the sun and to be between the earth and the',
#  'sun The centre of the epicycle of Mars Jupiter and Saturn were',
#  'supposed to be further away than the sun Mercury and Venus were',
#  'supposed to revolve in their epicycle in their own periodic time and',
#  'in the deferent round the earth in a year The major planet were',
#  'supposed to revolve in the deferent round the earth in their own',
#  'periodic time and in their epicycle once in a year',
#  'It did not occur to Ptolemy to place the centre of the epicycle of',
#  'Mercury and Venus at the sun and to extend the same system to the',
#  'major planet Something of this sort had been proposed by the',
#  'Egyptians we are told by Cicero and others and wa accepted by',
#  'Tycho Brahe and wa a true a representation of the relative motion',
#  'in the solar system a when we suppose the sun to be fixed and the',
#  'earth to revolve',
#  'The cumbrous system advocated by Ptolemy answered it purpose',
#  'enabling him to predict astronomical event approximately He improved',
#  'the lunar theory considerably and discovered minor inequality which',
#  'could be allowed for by the addition of new epicycle We may look',
#  'upon these epicycle of Apollonius and the excentric of Hipparchus',
#  'a the response of these astronomer to the demand of Plato for',
#  'uniform circular motion Their use became more and more confirmed',
#  'until the seventeenth century when the accurate observation of Tycho',
#  'Brahe enabled Kepler to abolish these purely geometrical makeshift',
#  'and to substitute a system in which the sun became physically it',
#  'controller',
#  'FOOTNOTES',
#  'vol pp',
#  '',
#  'Πληιάδας τʽ δύοντα βοώτην',
#  'ʼΆρκτον καλέουσιν',
#  'ʽΉ στρέφεται ʼΩρίωνα δοκεύει',
#  'λοετρων',
#  'The Pleiades and Boötes that setteth late and the Bear',
#  'which they likewise call the Wain which turneth ever in one',
#  'place and keepeth watch upon Orion and alone hath no part in',
#  'the bath of the ocean',
#  'See Pearson in the Camb Phil Soc vol pt p',
#  'on whose authority the above statement are made',
#  'See for definition',
#  'THE REIGN OF EPICYCLES FROM PTOLEMY TO COPERNICUS',
#  'After Ptolemy had published his book there seemed to be nothing more',
#  'to do for the solar system except to go on observing and finding more',
#  'and more accurate value for the constant involved the period',
#  'of revolution the diameter of the deferent and it ratio to that',
#  'of the epicycle the distance of the excentric from the centre',
#  'of the deferent and the position of the line of apse besides the',
#  'inclination and position of the plane of the planet orbit The only',
#  'object ever aimed at in those day wa to prepare table for',
#  'predicting the place of the planet It wa not a mechanical problem',
#  'there wa no notion of a governing law of force',
#  'From this time onwards all interest in astronomy seemed in Europe at',
#  'least to sink to a low ebb When the Caliph Omar in the middle of',
#  'the seventh century burnt the library of Alexandria which had been',
#  'the centre of intellectual progress that centre migrated to Baghdad',
#  'and the Arabs became the leader of science and philosophy In',
#  'astronomy they made careful observation In the middle of the ninth',
#  'century Albategnius a Syrian prince improved the value of',
#  'excentricity of the sun orbit observed the motion of the moon',
#  'apse and thought he detected a smaller progression of the sun',
#  'apse His table were much more accurate than Ptolemy Abul Wefa in',
#  'the tenth century seems to have discovered the moon variation',
#  'Meanwhile the Moors were leader of science in the west and Arzachel',
#  'of Toledo improved the solar table very much Ulugh Begh grandson of',
#  'the great Tamerlane the Tartar built a fine observatory at Samarcand',
#  'in the fifteenth century and made a great catalogue of star the',
#  'first since the time of Hipparchus',
#  'At the close of the fifteenth century King Alphonso of Spain employed',
#  'computer to produce the Alphonsine Tables Purbach',
#  'translated Ptolemy book and observation were carried out in',
#  'Germany by Müller known a Regiomontanus and Waltherus',
#  'Nicolai Copernicus a Sclav wa born in at Thorn in Polish',
#  'Prussia He studied at Cracow and in Italy He wa a priest and',
#  'settled at Frauenberg He did not undertake continuous observation',
#  'but devoted himself to simplifying the planetary system and devising',
#  'mean for more accurately predicting the position of the sun moon',
#  'and planet He had no idea of framing a solar system on a dynamical',
#  'basis His great object wa to increase the accuracy of the',
#  'calculation and the table The result of his cogitation were',
#  'printed just before his death in an interesting book',
#  'Revolutionibus Orbium It is only by careful reading of',
#  'this book that the true position of Copernicus can be realised He',
#  'noticed that Nicetas and others had ascribed the apparent diurnal',
#  'rotation of the heaven to a real daily rotation of the earth about',
#  'it axis in the opposite direction to the apparent motion of the',
#  'star Also in the writing of Martianus Capella he learnt that the',
#  'Egyptians had supposed Mercury and Venus to revolve round the sun and',
#  'to be carried with him in his annual motion round the earth He',
#  'noticed that the same supposition if extended to Mars Jupiter and',
#  'Saturn would explain easily why they and especially Mars seem so',
#  'much brighter in opposition For Mars would then be a great deal',
#  'nearer to the earth than at other time It would also explain the',
#  'retrograde motion of planet when in opposition',
#  'We must here notice that at this stage Copernicus wa actually',
#  'confronted with the system accepted later by Tycho Brahe with the',
#  'earth fixed But he now recalled and accepted the view of Pythagoras',
#  'and others according to which the sun is fixed and the earth',
#  'revolves and it must be noted that geometrically there is no',
#  'difference of any sort between the Egyptian or Tychonic system and',
#  'that of Pythagoras a revived by Copernicus except that on the latter',
#  'theory the star ought to seem to move when the earth change it',
#  'position a test which failed completely with the rough mean of',
#  'observation then available The radical defect of all solar system',
#  'previous to the time of Kepler wa the slavish yielding to',
#  'Plato dictum demanding uniform circular motion for the planet and',
#  'the consequent evolution of the epicycle which wa fatal to any',
#  'conception of a dynamical theory',
#  'Copernicus could not sever himself from this obnoxious tradition',
#  'It is true that neither the Pythagorean nor the system',
#  'required epicycle for explaining retrograde motion a the Ptolemaic',
#  'theory did Furthermore either system could use the excentric of',
#  'Hipparchus to explain the irregular motion known a the equation of',
#  'the centre But Copernicus remarked that he could also use an',
#  'epicycle for this purpose or that he could use both an excentric and',
#  'an epicycle for each planet and so bring theory still closer into',
#  'accord with observation And this he proceeded to do Moreover',
#  'observer had found irregularity in the moon motion due a we',
#  'now know to the disturbing attraction of the sun To correct for',
#  'these irregularity Copernicus introduced epicycle on epicycle in the',
#  'lunar orbit',
#  'This is in it main feature the system propounded by Copernicus But',
#  'attention must to state the case fully be drawn to two point to be',
#  'found in his first and sixth book respectively The first point',
#  'relates to the season and it show a strange ignorance of the law',
#  'of rotating body To use the word of Delambre in drawing',
#  'attention to the strange conception',
#  'he imagined that the earth revolving round the sun ought always to',
#  'show to it the same face the contrary phenomenon surprised him to',
#  'explain them he invented a third motion and added it to the two',
#  'real motion rotation and orbital revolution By this third motion',
#  'the earth he held made a revolution on itself and on the pole of',
#  'the ecliptic once a year Copernicus did not know that motion in',
#  'a straight line is the natural motion and that motion in a curve is',
#  'the resultant of several movement He believed with Aristotle',
#  'that circular motion wa the natural one',
#  'Copernicus made this rotation of the earth axis about the pole of',
#  'the ecliptic retrograde opposite to the orbital revolution',
#  'and by making it perform more than one complete revolution in a year',
#  'the added part being of the whole he wa able to include the',
#  'precession of the equinox in his explanation of the season His',
#  'explanation of the season is given on leaf of his book the page',
#  'of this book are not all numbered only alternate page or leaf',
#  'In his sixth book he discus the inclination of the planetary orbit',
#  'to the ecliptic In regard to this the theory of Copernicus is unique',
#  'and it will be best to explain this in the word of Grant in his great',
#  'work He say',
#  'Copernicus a we have already remarked did not attack the',
#  'principle of the epicyclical theory he merely sought to make it',
#  'more simple by placing the centre of the earth orbit in the centre',
#  'of the universe This wa the point to which the motion of the',
#  'planet were referred for the plane of their orbit were made to',
#  'pas through it and their point of least and greatest velocity',
#  'were also determined with reference to it By this arrangement the',
#  'sun wa situate mathematically near the centre of the planetary',
#  'system but he did not appear to have any physical connexion with',
#  'the planet a the centre of their motion',
#  'According to Copernicus sixth book the plane of the planetary',
#  'orbit do not pas through the sun and the line of apse do not pas',
#  'through to the sun',
#  'Such wa the theory advanced by Copernicus The earth move in an',
#  'epicycle on a deferent whose centre is a little distance from the',
#  'sun The planet move in a similar way on epicycle but their',
#  'deferents have no geometrical or physical relation to the sun The',
#  'moon move on an epicycle centred on a second epicycle itself centred',
#  'on a deferent excentric to the earth The earth axis rotates about',
#  'the pole of the ecliptic making one revolution and a',
#  'thousandth part of a revolution in the sidereal year in the opposite',
#  'direction to it orbital motion',
#  'In view of this fanciful structure it must be noted in fairness to',
#  'Copernicus that he repeatedly state that the reader is not obliged',
#  'to accept his system a showing the real motion that it doe not',
#  'matter whether they be true even approximately or not so long a',
#  'they enable u to compute table from which the place of the planet',
#  'among the star can be predicted He say that whoever is not',
#  'satisfied with this explanation must be contented by being told that',
#  'mathematics are for mathematician Mathematicis mathematica',
#  'scribuntur',
#  'At the same time he express his conviction over and over again that',
#  'the earth is in motion It is with him a pious belief just a it wa',
#  'with Pythagoras and his school and with Aristarchus But a Dreyer',
#  'say in his most interesting book proof of the',
#  'physical truth of his system Copernicus had given none and could give',
#  'none any more than Pythagoras or Aristarchus',
#  'There wa nothing so startlingly simple in his system a to lead the',
#  'cautious astronomer to accept it a there wa in the later Keplerian',
#  'system and the absence of parallax in the star seemed to condemn his',
#  'system which had no physical basis to recommend it and no',
#  'simplification at all over the system to which',
#  'Copernicus himself drew attention It ha been necessary to devote',
#  'perhaps undue space to the interesting work of Copernicus because by',
#  'a curious chance his name ha become so widely known He ha been',
#  'spoken of very generally a the founder of the solar system that is',
#  'now accepted This seems unfair and on reading over what ha been',
#  'written about him at different time it will be noticed that the',
#  'astronomer those who have evidently read his great book are very',
#  'cautious in the word with which they eulogise him and refrain from',
#  'attributing to him the foundation of our solar system which is',
#  'entirely due to Kepler It is only the more popular writer who give',
#  'the idea that a revolution had been effected when Pythagoras system',
#  'wa revived and when Copernicus supported his view that the earth',
#  'move and is not fixed',
#  'It may be easy to explain the association of the name of Copernicus',
#  'with the Keplerian system But the time ha long passed when the',
#  'historian can support in any way this popular error which wa started',
#  'not by astronomer acquainted with Kepler work but by those who',
#  'desired to put the Church in the wrong by extolling Copernicus',
#  'Copernicus dreaded much the abuse he expected to receive from',
#  'philosopher for opposing the authority of Aristotle who had declared',
#  'that the earth wa fixed So he sought and obtained the support of',
#  'the Church dedicating his great work to Pope Paul III in a lengthy',
#  'explanatory epistle The Bishop of Cracow set up a memorial tablet in',
#  'his honour',
#  'Copernicus wa the most refined exponent and almost the last',
#  'representative of the Epicyclical School As ha been already',
#  'stated his successor Tycho Brahe supported the same use of',
#  'epicycle and excentrics a Copernicus though he held the earth to be',
#  'fixed But Tycho Brahe wa eminently a practical observer and took',
#  'little part in theory and his observation formed so essential a',
#  'portion of the system of Kepler that it is only fair to include his',
#  'name among these who laid the foundation of the solar system which we',
#  'accept',
#  'In now taking leave of the system of epicycle let it be remarked that',
#  'it ha been held up to ridicule more than it deserves On reading',
#  'Airy account of epicycle in the beautifully clear language of his',
#  'Lectures on the impression is made that the',
#  'jointed bar there spoken of for describing the circle were supposed',
#  'to be real This is no more the case than that the sphere of Eudoxus',
#  'and Callippus were supposed to be real Both were introduced only to',
#  'illustrate the mathematical conception upon which the solar',
#  'planetary and lunar table were constructed The epicycle',
#  'represented nothing more nor le than the first term in the Fourier',
#  'series which in the last century ha become a basis of such',
#  'calculation both in astronomy and physic generally',
#  'Illustration QUADRANS MURALIS SIVE TICHONICUS With portrait of',
#  'Tycho Brahe instrument painted on the wall showing',
#  'assistant using the sight watching the clock and recording From',
#  'the author copy of the Instauratæ',
#  'FOOTNOTES',
#  'For definition see',
#  '',
#  'For definition see',
#  'For definition see',
#  'In his great book Copernicus say The movement of the heavenly',
#  'body is uniform circular perpetual or else composed of circular',
#  'movement In this he proclaimed himself a follower of Pythagoras',
#  'see a also when he say The world is spherical because the',
#  'sphere is of all figure the most perfect Delambre',
#  'Mod pp',
#  'Kepler tell u that Tycho Brahe wa pleased with this',
#  'device and adapted it to his own system',
#  'vol',
#  'of Phys vii',
#  'Est enim Astronomi proprium historiam motuum coelestium',
#  'diligenti et artificiosa observatione colligere Deinde causa',
#  'earundem seu hypothesis cum veras assequi nulla ratione possit',
#  'Neque enim necesse est ea hypothesis esse veras imo ne',
#  'verisimiles quidem sed sufficit hoc usum si calculum observationibus',
#  'congruentem exhibeant',
#  'BOOK II THE DYNAMICAL PERIOD',
#  'DISCOVERY OF THE TRUE SOLAR SYSTEM TYCHO BRAHE KEPLER',
#  'During the period of the intellectual and aesthetic revival at the',
#  'beginning of the sixteenth century the spirit of the age wa',
#  'fostered by the invention of printing by the downfall of the',
#  'Byzantine Empire and the scattering of Greek fugitive carrying the',
#  'treasure of literature through Western Europe by the work of',
#  'Raphael and Michael Angelo by the Reformation and by the extension',
#  'of the known world through the voyage of Spaniards and Portuguese',
#  'During that period there came to the front the founder of accurate',
#  'observational astronomy Tycho Brahe a Dane born in of noble',
#  'parent wa the most distinguished diligent and accurate observer',
#  'of the heaven since the day of Hipparchus year before',
#  'Tycho wa devoted entirely to his science from childhood and the',
#  'opposition of his parent only stimulated him in his effort to',
#  'overcome difficulty He soon grasped the hopelessness of the old',
#  'deductive method of reasoning and decided that no theory ought to',
#  'be indulged in until preparation had been made by the accumulation of',
#  'accurate observation We may claim for him the title of founder of',
#  'the inductive method',
#  'For a complete life of this great man the reader is referred to',
#  'Dreyer Edinburgh containing a complete',
#  'bibliography The present notice must be limited to noting the work',
#  'done and the quality of character which enabled him to attain his',
#  'scientific aim and which have been conspicuous in many of his',
#  'successor',
#  'He studied in Germany but King Frederick of Denmark appreciating his',
#  'great talent invited him to carry out his life work in that',
#  'country He granted to him the island of Hveen gave him a pension',
#  'and made him a canon of the Cathedral of Roskilde On that island',
#  'Tycho Brahe built the splendid observatory which he called Uraniborg',
#  'and later a second one for his assistant and student called',
#  'Stjerneborg These he fitted up with the most perfect instrument and',
#  'never lost a chance of adding to his stock of careful observation',
#  'The account of all these instrument and observation printed at his',
#  'own press on the island wa published by Tycho Brahe himself and the',
#  'admirable and numerous engraving bear witness to the excellence of',
#  'design and the stability of his instrument',
#  'His mechanical skill wa very great and in his workmanship he wa',
#  'satisfied with nothing but the best He recognised the importance of',
#  'rigidity in the instrument and whereas these had generally been',
#  'made of wood he designed them in metal His instrument included',
#  'armillae like those which had been used in Alexandria and other',
#  'armillae designed by himself sextant mural quadrant large',
#  'celestial globe and various instrument for special purpose He',
#  'lived before the day of telescope and accurate clock He invented',
#  'the method of the degree on the arc of an instrument by',
#  'transversals somewhat in the way that Pedro Nunez had proposed',
#  'He originated the true system of observation and reduction of',
#  'observation recognising the fact that the best instrument in the',
#  'world is not perfect and with each of his instrument he set to work',
#  'to find out the error of graduation and the error of mounting the',
#  'necessary correction being applied to each observation',
#  'When he wanted to point his instrument exactly to a star he wa',
#  'confronted with precisely the same difficulty a is met in gunnery and',
#  'The sight and the object aimed at can not be in focus',
#  'together and a great deal depends on the form of sight Tycho Brahe',
#  'invented and applied to the pointer of his instrument an',
#  'of variable area like the iris diaphragm used now in',
#  'photography This enabled him to get the best result with star of',
#  'different brightness The telescope not having been invented he',
#  'could not use a a we now do in gunnery This not',
#  'only remove the difficulty of focussing but make the minimum',
#  'visible angle smaller Helmholtz ha defined the minimum angle',
#  'measurable with the naked eye a being one minute of arc In view of',
#  'this it is simply marvellous that when the position of Tycho',
#  'standard star are compared with the best modern catalogue his',
#  'probable error in right ascension is only and in declination',
#  'only',
#  'Clocks of a sort had been made but Tycho Brahe found them so',
#  'unreliable that he seldom used them and many of his',
#  'were made by measuring the angular distance from known star',
#  'Taking into consideration the absence of either a telescope or a',
#  'clock and reading his account of the labour he bestowed upon each',
#  'observation we must all agree that Kepler who inherited these',
#  'observation in wa justified under the condition then',
#  ...]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# %%
X_train_tokens = tokenizer.texts_to_sequences(corpus)
X_train_tokens
# Out:
# [[1600, 2315, 2316, 2, 179, 2, 57, 9, 535, 893],
#  [1256, 179, 2, 57],
#  [894, 535, 893],
#  [322, 132, 610, 74, 21, 1, 2317, 9, 2318, 6, 2319],
#  [1040, 611],
#  [179, 2, 57],
#  [9],
#  [535, 893],
#  [2320],
#  [1601, 536, 2, 692, 1257, 1258, 1040, 1259],
#  [894, 2, 1, 323, 2, 282, 2321, 52, 2, 1, 2322, 2],
#  [2323, 779],
#  [2324],
#  [1602],
#  [113, 612, 1, 537, 71],
#  [1041, 57, 3, 895],
#  [206, 57, 225, 3, 693],
#  [206, 613, 57],
#  [1, 1042, 2, 1603, 21, 338, 5, 124],
#  [113, 1043, 1, 432, 71],
#  [66, 2, 1, 145, 56, 61, 102, 140, 84],
#  [149, 3, 1, 79, 1604, 2, 481, 9, 896, 779],
#  [132, 610, 74, 62, 2, 324, 141],
#  [74, 1605, 238, 614, 694, 325, 779],
#  [66, 2, 63, 897, 121, 615, 226, 3, 150],
#  [283],
#  [113, 1044, 33],
#  [1260, 2, 780, 326, 2, 1, 56, 61],
#  [179, 2, 1, 79, 216],
#  [113, 1606, 1, 217, 71],
#  [1, 26],
#  [1, 45, 3, 897],
#  [1261, 3, 1607],
#  [1, 1608, 3, 371],
#  [2325],
#  [1602],
#  [29, 616, 28, 23, 51, 6, 27, 898, 5, 482, 1, 617, 2],
#  [538, 253, 6, 1, 254, 2, 172, 66, 3],
#  [9, 1609, 1, 136, 122, 2, 173, 2, 1, 136, 327, 5],
#  [194, 189, 1262, 239, 5, 1, 206, 68, 37, 103, 1610, 6, 4, 179],
#  [2, 57, 2, 781, 326, 5, 227, 4, 2326, 18, 539, 40, 18],
#  [899, 57, 433, 4, 395, 1611, 57, 3],
#  [201, 150, 4, 113, 18, 1263, 57, 1045, 2, 97, 2],
#  [27, 12, 1046, 483, 15, 1047, 1, 254, 2, 253, 3],
#  [202, 20, 8, 12, 1, 240, 2, 19, 179, 5, 1048],
#  [1, 254, 2, 372, 202, 12, 228, 9, 1, 396, 1612, 2],
#  [1264, 17, 101, 21, 63, 122, 2, 173, 4, 109, 4, 9, 1],
#  [1049, 2, 101, 1, 1613, 1050, 2, 37, 327, 540, 30, 255, 5],
#  [1614, 21, 7, 2, 72, 327, 25, 8, 12, 1, 900, 2, 63],
#  [122, 2, 173, 7, 194, 4, 2327, 2328, 5, 7, 1050, 3, 19, 12],
#  [2329, 3, 1265, 2330, 782, 2331, 1, 56],
#  [61, 4, 4, 537, 298, 84, 3, 74, 1615, 1, 122],
#  [2, 173, 117, 4, 432, 37, 782, 1613, 1050, 5],
#  [1051, 1, 484, 2, 101, 40, 5, 2332, 4, 901, 2, 618],
#  [92, 24, 23, 339, 5, 7, 2, 84, 40, 74, 25, 1, 122, 2, 173],
#  [10, 136],
#  [93, 218, 63, 122, 2, 173, 38, 902, 9, 1, 541, 2, 63],
#  [155, 6, 7, 61, 2, 695, 20, 55, 1266, 542, 32, 7],
#  [542, 103, 241, 12, 5, 1616, 126, 7, 4, 485, 4, 12, 2333, 5],
#  [485, 783, 784, 373, 40, 12, 37, 2, 1, 101, 696, 9, 1, 485],
#  [783,
#   784,
#   373,
#   48,
#   7,
#   55,
#   92,
#   299,
#   95,
#   783,
#   784,
#   3,
#   373,
#   38,
#   145,
#   93,
#   4,
#   12,
#   145],
#  [5, 80, 543, 125, 2334, 5, 1051, 32, 7, 12, 1617, 6],
#  [485, 783, 784, 3, 373, 397, 1, 1618, 697, 2, 4, 300],
#  [1052, 1267, 1, 1268, 2, 1, 372, 619, 4, 4, 1269],
#  [2335, 15, 8, 374, 1, 63, 122, 2, 173, 1053, 9, 74],
#  [903, 5, 904, 543, 5, 209, 7, 48, 203, 4, 174, 49, 38],
#  [1270, 84, 210, 62, 783, 784, 373, 34, 905, 16, 74],
#  [62, 2, 141, 4, 68, 37, 1619, 67, 85, 1, 300],
#  [64, 19, 1268, 2, 1, 372, 906, 3, 68, 37, 12, 67],
#  [2336, 2, 1, 1620, 2, 1, 1269, 697, 180],
#  [542, 20, 239, 86, 28, 30, 1054, 1055, 1, 298, 2],
#  [73, 210, 133],
#  [27, 1056, 2337, 21, 1, 698, 2, 19, 179, 785, 5],
#  [229, 1, 2338, 2339, 2, 1, 43, 300, 64],
#  [74, 907, 2, 301, 5, 1, 2340, 18, 1, 2341, 2342, 5],
#  [106, 32, 486, 97, 63, 66, 1271, 164, 8, 92, 13, 2343, 786],
#  [15, 302, 15, 908, 3, 15, 1272, 1, 43],
#  [64, 2344, 5, 699, 1057, 219, 4, 145, 24, 700],
#  [451, 3, 424, 5, 1, 753, 2, 14, 99, 29],
#  [2, 425, 1153, 119, 1, 1899, 2893, 98, 86, 6],
#  [215, 19, 347, 90, 5, 717, 1, 264, 139, 16, 22, 2],
#  [136, 572, 1, 79, 30, 160, 23, 451, 11],
#  [100, 30, 142, 4, 4, 55, 86, 241, 6, 1898, 19, 30],
#  [73, 1761, 1, 561, 2, 2894, 25, 195, 1, 988],
#  [454, 362, 1127, 2895, 28, 1423, 1, 988, 362],
#  [1424, 16, 1, 1900, 590, 4, 91, 37, 276, 2, 389, 6, 173, 2],
#  [19, 8, 12, 1154, 1425, 7, 50, 1, 88, 2, 102],
#  [989, 22, 38, 417, 16, 1, 264, 234, 261, 14],
#  [732, 200, 6, 664, 1155, 12, 73, 3, 6, 1156],
#  [73],
#  [2896, 2, 4, 1125, 39, 23, 51, 25, 102, 140, 41, 106, 48],
#  [2897, 7, 11, 1901, 98, 106, 3, 80, 2, 14],
#  [34, 51, 9, 754, 1, 1157, 69, 21, 159, 22],
#  [1410, 117, 1426, 1, 852, 2, 729, 4, 79, 40, 4],
#  [423, 3, 846, 14, 637, 2, 1, 665, 11, 2898, 107, 97],
#  [33, 55, 94, 32, 859, 7, 84, 77, 1902, 27],
#  [33, 6, 10, 1903, 505, 1, 1069, 93],
#  ...]

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 4411

# %%
items = tokenizer.word_index.items()

# %% [markdown]
# ## Creating the Skipgram Model:

# %%
dim_embedddings = 300

# inputs
inputs = Input(shape=(1, ), dtype='int32')
w = Embedding(vocab_size, dim_embedddings)(inputs)

# context
c_inputs = Input(shape=(1, ), dtype='int32')
c  = Embedding(vocab_size, dim_embedddings)(c_inputs)

d = Dot(axes=2)([w, c])

d = Reshape((1,), input_shape=(1, 1))(d)
d = Activation('sigmoid')(d)

model = Model(inputs=[inputs, c_inputs], outputs=d)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 300)       1323300     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 300)       1323300     input_2[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1, 1)         0           embedding_1[0][0]
#                                                                  embedding_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           dot_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           reshape_1[0][0]
# ==================================================================================================
# Total params: 2,646,600
# Trainable params: 2,646,600
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# ## Training the model:

# %%
# %%time
n_epochs = 15
for epoch in range(n_epochs):
    loss = 0.
    for i, doc in enumerate(X_train_tokens):
        data, labels = skipgrams(sequence=doc, vocabulary_size=vocab_size, window_size=4)
        x = [np.array(x) for x in zip(*data)]
        y = np.array(labels, dtype=np.int32)
        if x:
            loss += model.train_on_batch(x, y)

    print('Epoch:', epoch, '\tLoss:', loss)
# Out:
# Epoch: 0 	Loss: 1855.122561082244
# Epoch: 1 	Loss: 1490.9883154407144
# Epoch: 2 	Loss: 1388.3679221607745
# Epoch: 3 	Loss: 1270.372354991734
# Epoch: 4 	Loss: 1164.389208954759
# Epoch: 5 	Loss: 1063.671567552723
# Epoch: 6 	Loss: 982.9436835721135
# Epoch: 7 	Loss: 913.5112223466858
# Epoch: 8 	Loss: 857.7043578715529
# Epoch: 9 	Loss: 809.6147848761175
# Epoch: 10 	Loss: 771.9398003910901
# Epoch: 11 	Loss: 743.7286821631715
# Epoch: 12 	Loss: 722.955197765812
# Epoch: 13 	Loss: 703.9326986923697
# Epoch: 14 	Loss: 685.0070044388121
# Wall time: 4min 59s

# %% [markdown]
# ## Saving the model:

# %%
f = open('../data/word2vec-skipgrams1.txt' ,'w', encoding="utf8")
f.write('{} {}\n'.format(vocab_size-1, dim_embedddings))

weights = model.get_weights()[0]
for word, i in items:
    f.write('{} {}\n'.format(word, ' '.join(map(str, list(weights[i, :])))))
f.close()

# %% [markdown]
# ## Loading the model:

# %%
w2v = gensim.models.KeyedVectors.load_word2vec_format('../data/word2vec-skipgrams1.txt', binary=False)

# %%
w2v.most_similar(positive=['solar'])
# Out:
# C:\Anaconda36\envs\tf111_gpu\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('gaseous', 0.4597316086292267),
#  ('researches', 0.4340711534023285),
#  ('harmful', 0.4325682818889618),
#  ('physics', 0.4134013056755066),
#  ('system', 0.41045206785202026),
#  ('news', 0.39892005920410156),
#  ('compressed', 0.3597968816757202),
#  ('nautical', 0.35958218574523926),
#  ('substitute', 0.3580801486968994),
#  ('toledo', 0.3563697040081024)]

# %%
w2v.most_similar(positive=['system'])
# Out:
# [('advocated', 0.4853593111038208),
#  ('solar', 0.4104520082473755),
#  ('main', 0.40048810839653015),
#  ('relationship', 0.3770222067832947),
#  ('answered', 0.3546488583087921),
#  ('golden', 0.33952847123146057),
#  ('clue', 0.33863192796707153),
#  ('harmful', 0.33825457096099854),
#  ('driving', 0.3371925354003906),
#  ('predominance', 0.33416372537612915)]

# %%
w2v.most_similar(positive=['kepler'])
# Out:
# [('wanderer', 0.5605933666229248),
#  ('johannes', 0.5162597894668579),
#  ('reitlinger', 0.5112121105194092),
#  ('independence', 0.4941261410713196),
#  ('strassburg', 0.4905438721179962),
#  ('yielding', 0.4500398635864258),
#  ('slavish', 0.44416677951812744),
#  ('contemplated', 0.44190627336502075),
#  ('abolish', 0.4218079745769501),
#  ('johann', 0.4171288013458252)]

# %% [markdown]
# ## References:
#
# https://keras.io/preprocessing/sequence/
#
# https://www.tensorflow.org/tutorials/representation/word2vec
