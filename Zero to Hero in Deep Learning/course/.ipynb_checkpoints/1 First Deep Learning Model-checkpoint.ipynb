# %% [markdown]
# # First Deep Learning Model

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles
# Out:
# C:\Users\prudi\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 1s 900us/step - loss: 0.6724 - accuracy: 0.6200
# Epoch 2/20
# 1000/1000 [==============================] - 0s 40us/step - loss: 0.6016 - accuracy: 0.8030
# Epoch 3/20
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.4818 - accuracy: 0.8940
# Epoch 4/20
# 1000/1000 [==============================] - 0s 40us/step - loss: 0.3477 - accuracy: 0.9570
# Epoch 5/20
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.2508 - accuracy: 0.9960
# Epoch 6/20
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1878 - accuracy: 1.0000
# Epoch 7/20
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1468 - accuracy: 1.0000
# Epoch 8/20
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1203 - accuracy: 1.0000
# Epoch 9/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.1013 - accuracy: 1.0000
# Epoch 10/20
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.0876 - accuracy: 1.0000
# Epoch 11/20
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.0767 - accuracy: 1.0000
# Epoch 12/20
# 1000/1000 [==============================] - 0s 40us/step - loss: 0.0684 - accuracy: 1.0000
# Epoch 13/20
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 14/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 15/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 16/20
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 17/20
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 18/20
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 19/20
# 1000/1000 [==============================] - 0s 47us/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 20/20
# 1000/1000 [==============================] - 0s 42us/step - loss: 0.0359 - accuracy: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
